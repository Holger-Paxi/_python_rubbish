# %%
import pandas as pd

# %%
link = 'https://en.wikipedia.org/wiki/List_of_player_salaries_in_the_NHL'
table = pd.read_html(link)

# %%
table
# Out:
# [                                                   0
#  0  Contents 1 Top 20 salaries in the NHL since 19...,
#      Rank         Player name   Salary (USD)  \
#  0      1       Sidney Crosby  $ 129,340,243
#  1      2        Jaromír Jágr  $ 128,139,753
#  2      3  Alexander Ovechkin  $ 123,220,892
#  3      4          Shea Weber  $ 120,030,338
#  4      5  Vincent Lecavalier  $ 114,504,703
#  5      6       Evgeni Malkin  $ 114,220,892
#  6      7       Chris Pronger  $ 111,379,268
#  7      8        Joe Thornton  $ 109,887,195
#  8      9         Zach Parise  $ 107,910,064
#  9     10        Patrick Kane  $ 105,837,195
#  10    11      Jonathan Toews  $ 105,762,195
#  11    12        Anže Kopitar  $ 105,454,878
#  12    13       Brad Richards  $ 104,511,911
#  13    14          Ryan Suter  $ 104,360,064
#  14    15    Henrik Lundqvist  $ 102,783,390
#  15    16         Zdeno Chára   $ 98,788,695
#  16    17           Joe Sakic   $ 96,379,481
# ...

# %%
table[0]
# Out:
#                                                    0
# 0  Contents 1 Top 20 salaries in the NHL since 19...

# %%
table[1]
# Out:
#     Rank         Player name   Salary (USD)  \
# 0      1       Sidney Crosby  $ 129,340,243
# 1      2        Jaromír Jágr  $ 128,139,753
# 2      3  Alexander Ovechkin  $ 123,220,892
# 3      4          Shea Weber  $ 120,030,338
# 4      5  Vincent Lecavalier  $ 114,504,703
# 5      6       Evgeni Malkin  $ 114,220,892
# 6      7       Chris Pronger  $ 111,379,268
# 7      8        Joe Thornton  $ 109,887,195
# 8      9         Zach Parise  $ 107,910,064
# 9     10        Patrick Kane  $ 105,837,195
# 10    11      Jonathan Toews  $ 105,762,195
# 11    12        Anže Kopitar  $ 105,454,878
# 12    13       Brad Richards  $ 104,511,911
# 13    14          Ryan Suter  $ 104,360,064
# 14    15    Henrik Lundqvist  $ 102,783,390
# 15    16         Zdeno Chára   $ 98,788,695
# 16    17           Joe Sakic   $ 96,379,481
# 17    18      Marián Gáborík   $ 96,319,243
# 18    19     Patrick Marleau   $ 96,209,445
# 19    20         Carey Price   $ 96,194,368
#
# ...

# %%
table[2]
# Out:
#      Season           Player name      Salary[3]
# 0   1917–18         Newsy Lalonde     CAN $1,300
# 1   1921–22         Newsy Lalonde     CAN $2,000
# 2   1923–24          Howie Morenz     CAN $3,500
# 3   1925–26     Frank Fredrickson     CAN $3,500
# 4   1942–43          Ronnie Rowe†     CAN $3,000
# 5   1953–54         Jean Beliveau    CAN $21,000
# 6   1954–55         Jean Beliveau    CAN $21,000
# 7   1955–56         Jean Beliveau    CAN $21,000
# 8   1956–57         Jean Beliveau    CAN $21,000
# 9   1957–58         Jean Beliveau    CAN $21,000
# 10  1959–60           Doug Harvey    CAN $25,000
# 11  1959–60       Maurice Richard    CAN $25,000
# 12  1962–63       Frank Mahovlich    CAN $25,000
# 13  1963–64  (NHL minimum salary)     CAN $7,000
# 14  1963–64         Phil Esposito     US $54,990
# 15  1965–66          Gump Worsley    CAN $28,000
# 16  1966–67             Bobby Orr     US $35,000
# 17  1967–68             Bobby Orr     US $35,000
# ...

# %%
table[3]
# Out:
#   .mw-parser-output .navbar{display:inline;font-size:88%;font-weight:normal}.mw-parser-output .navbar-collapse{float:left;text-align:left}.mw-parser-output .navbar-boxtext{word-spacing:0}.mw-parser-output .navbar ul{display:inline-block;white-space:nowrap;line-height:inherit}.mw-parser-output .navbar-brackets::before{margin-right:-0.125em;content:"[ "}.mw-parser-output .navbar-brackets::after{margin-left:-0.125em;content:" ]"}.mw-parser-output .navbar li{word-spacing:-0.125em}.mw-parser-output .navbar a>span,.mw-parser-output .navbar a>abbr{text-decoration:inherit}.mw-parser-output .navbar-mini abbr{font-variant:small-caps;border-bottom:none;text-decoration:none;cursor:inherit}.mw-parser-output .navbar-ct-full{font-size:114%;margin:0 7em}.mw-parser-output .navbar-ct-mini{font-size:114%;margin:0 4em}vteNational Hockey League-related lists and topics  \
# 0                                            History
# 1                                          Personnel
# ...
